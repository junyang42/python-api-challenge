# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from apikey import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
print("Beginning Data Retrieval")
print("_________________________")
a = 1
b = 1
city_name = []
cloudiness = []
country_name = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities:
    city_response = requests.get(query_url + city).json()
    # to check if the info is available for the given API called
    try:         
        city_name.append(city_response["name"])
        cloudiness.append(city_response["clouds"]["all"])
        country_name.append(city_response["sys"]["country"])
        humidity.append(city_response["main"]["humidity"])
        lat.append(city_response["coord"]["lat"])
        lng.append(city_response["coord"]["lon"])
        max_temp.append(city_response["main"]["temp"])
        wind_speed.append(city_response["wind"]["speed"])
        
        print(f"Processing Record {a} of Set {b} | {city}")     
        if a > 49:
            b += 1
            a = 1
        else:
            a = a + 1
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# _________________________
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | coihueco
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | saint-augustin
# Processing Record 5 of Set 1 | mataura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 1 | zambezi
# Processing Record 7 of Set 1 | codrington
# Processing Record 8 of Set 1 | cayenne
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | langen
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | lasa
# City not found. Skipping...
# Processing Record 14 of Set 1 | maniitsoq
# Processing Record 15 of Set 1 | reisterstown
# Processing Record 16 of Set 1 | dongkan
# City not found. Skipping...
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | aksarka
# Processing Record 23 of Set 1 | tarko-sale
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | xingyi
# Processing Record 26 of Set 1 | klaksvik
# Processing Record 27 of Set 1 | lubumbashi
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | redwater
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | tavricheskoye
# Processing Record 32 of Set 1 | launceston
# City not found. Skipping...
# Processing Record 33 of Set 1 | svetlaya
# Processing Record 34 of Set 1 | yulara
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 37 of Set 1 | pierre
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | samarai
# City not found. Skipping...
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | bubaque
# Processing Record 42 of Set 1 | saint george
# Processing Record 43 of Set 1 | port blair
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | loding
# Processing Record 46 of Set 1 | singkang
# City not found. Skipping...
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | thul
# Processing Record 2 of Set 2 | kortkeros
# Processing Record 3 of Set 2 | saint anthony
# Processing Record 4 of Set 2 | ahipara
# Processing Record 5 of Set 2 | oriximina
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | vallenar
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | sheridan
# Processing Record 10 of Set 2 | high level
# Processing Record 11 of Set 2 | kurilsk
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | flinders
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | meulaboh
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 20 of Set 2 | chuy
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | biak
# Processing Record 23 of Set 2 | grand-santi
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | ocean city
# Processing Record 26 of Set 2 | ternate
# Processing Record 27 of Set 2 | mount isa
# City not found. Skipping...
# Processing Record 28 of Set 2 | luangwa
# City not found. Skipping...
# Processing Record 29 of Set 2 | moron
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | bonthe
# Processing Record 34 of Set 2 | naze
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | spirit river
# Processing Record 37 of Set 2 | zyryanka
# Processing Record 38 of Set 2 | celica
# Processing Record 39 of Set 2 | narsaq
# Processing Record 40 of Set 2 | souillac
# Processing Record 41 of Set 2 | bayan
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | krasnoshchekovo
# Processing Record 44 of Set 2 | los llanos de aridane
# City not found. Skipping...
# Processing Record 45 of Set 2 | upernavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | kruisfontein
# Processing Record 48 of Set 2 
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | andros town
# Processing Record 29 of Set 4 | krasnoturansk
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | avera
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | ribnica
# Processing Record 34 of Set 4 | katobu
# Processing Record 35 of Set 4 | gizo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 4 | margate
# Processing Record 37 of Set 4 | oxkutzcab
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | sao joao da barra
# Processing Record 40 of Set 4 | pangai
# Processing Record 41 of Set 4 | maceio
# Processing Record 42 of Set 4 | beringovskiy
# Processing Record 43 of Set 4 | rosetta
# Processing Record 44 of Set 4 | rosarito
# Processing Record 45 of Set 4 | blackwater
# Processing Record 46 of Set 4 | forbes
# Processing Record 47 of Set 4 | bose
# Processing Record 48 of Set 4 | urusha
# Processing Record 49 of Set 4 | sawtell
# Processing Record 50 of Set 4 | dauphin
# Processing Record 1 of Set 5 | thouars
# Processing Record 2 of Set 5 | taoudenni
# Processing Record 3 of Set 5 | mpigi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 5 | san quintin
# City not found. Skipping...
# Processing Record 5 of Set 5 | kisangani
# Processing Record 6 of Set 5 | la ronge
# Processing Record 7 of Set 5 | nelson bay
# City not found. Skipping...
# Processing Record 8 of Set 5 | dogondoutchi
# Processing Record 9 of Set 5 | champerico
# Processing Record 10 of Set 5 | krasnyy klyuch
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | bethel
# Processing Record 13 of Set 5 | batagay-alyta
# City not found. Skipping...
# Processing Record 14 of Set 5 | ust-nera
# City not found. Skipping...
# Processing Record 15 of Set 5 | broome
# Processing Record 16 of Set 5 | berezanka
# Processing Record 17 of Set 5 | thompson
# Processing Record 18 of Set 5 | teknaf
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | mwinilunga
# City not found. Skipping...
# Processing Record 21 of Set 5 | melbu
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | anchorage
# Processing Record 24 of Set 5 | tres arroyos
# Processing Record 25 of Set 5 | chicama
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 5 | clyde river
# Processing Record 27 of Set 5 | avarua
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | fortuna
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | barsovo
# Processing Record 33 of Set 5 | pevek
# Processing Record 34 of Set 5 | kloulklubed
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | rong kwang
# Processing Record 37 of Set 5 | ushtobe
# Processing Record 38 of Set 5 | sterling
# Processing Record 39 of Set 5 | cove
# Processing Record 40 of Set 5 | gorgan
# Processing Record 41 of Set 5 | hambantota
# Processing Record 42 of Set 5 | yekaterinovka
# Processing Record 43 of Set 5 | grave
# Processing Record 44 of Set 5 | marzuq
# City not found. Skipping...
# Processing Record 45 of Set 5 | dingle
# Processing Record 46 of Set 5 | mudon
# Processing Record 47 of Set 5 | zhigansk
# Processing Record 48 of Set 5 | bani walid
# Processing Record 49 of Set 5 | nyurba
# Processing Record 50 of Set 5 | imeni poliny osipenko
# Processing Record 1 of Set 6 | bara
# Processing Record 2 of Set 6 | faanui
# Processing Record 3 of Set 6 | acapulco
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | freetown
# Processing Record 6 of Set 6 | kozhva
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | hauterive
# Processing Record 10 of Set 6 | tiksi
# Processing Record 11 of Set 6 | poum
# Processing Record 12 of Set 6 | raudeberg
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | alihe
# Processing Record 15 of Set 6 | ciudad guayana
# Processing Record 16 of Set 6 | portobelo
# Processing Record 17 of Set 6 | evensk
# Processing Record 18 of Set 6 | zhangye
# Processing Record 19 of Set 6 | libreville
# Processing Record 20 of Set 6 | waingapu
# City not found. Skipping...
# Processing Record 21 of Set 6 | whitehorse
# Processing Record 22 of Set 6 | kropotkin
# Processing Record 23 of Set 6 | cessnock
# City not found. Skipping...
# Processing Record 24 of Set 6 | san vicente
# Processing Record 25 of Set 6 | kamina
# Processing Record 26 of Set 6 | gobabis
# City not found. Skipping...
# Processing Record 27 of Set 6 | yongan
# Processing Record 28 of Set 6 | bambanglipuro
# Processing Record 29 of Set 6 | cockburn town
# City not found. Skipping...
# Processing Record 30 of Set 6 | trinidad
# Processing Record 31 of Set 6 | abha
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | atar
# Processing Record 34 of Set 6 | corrente
# City not found. Skipping...
# Processing Record 35 of Set 6 | san juan
# Processing Record 36 of Set 6 | algeciras
# Processing Record 37 of Set 6 | talcahuano
# Processing Record 38 of Set 6 | pachora
# Processing Record 39 of Set 6 | maryanskaya
# Processing Record 40 of Set 6 | nome
# Processing Record 41 of Set 6 | hualmay
# Processing Record 42 of Set 6 | san cristobal
# Processing Record 43 of Set 6 | puerto penasco
# Processing Record 44 of Set 6 | touros
# City not found. Skipping...
# Processing Record 45 of Set 6 | crotone
# Processing Record 46 of Set 6 | najran
# Processing Record 47 of Set 6 | coquimbo
# Processing Record 48 of Set 6 | nioro
# City not found. Skipping...
# Processing Record 49 of Set 6 | saint-francois
# Processing Record 50 of Set 6 | la romana
# Processing Record 1 of Set 7 | arlit
# Processing Record 2 of Set 7 | saldanha
# Processing Record 3 of Set 7 | hamilton
# Processing Record 4 of Set 7 | doctor juan leon mallorquin
# Processing Record 5 of Set 7 | beloha
# Processing Record 6 of Set 7 | staryy nadym
# Processing Record 7 of Set 7 | vagur
# Processing Record 8 of Set 7 | waipawa
# Processing Record 9 of Set 7 | ngerengere
# Processing Record 10 of Set 7 | walvis bay
# Processing Record 11 of Set 7 | sorland
# Processing Record 12 of Set 7 | kumo
# Processing Record 13 of Set 7 | vestmannaeyjar
# Processing Record 14 of Set 7 | port said
# Processing Record 15 of Set 7 | kheralu
# Processing Record 16 of Set 7 | illapel
# Processing Record 17 of Set 7 | ponta delgada
# Processing Record 18 of Set 7 | aklavik
# Processing Record 19 of Set 7 | lensk
# Processing Record 20 of Set 7 | innisfail
# Processing Record 21 of Set 7 | svay rieng
# City not found. Skipping...
# Processing Record 22 of Set 7 | ust-kulom
# City not found. Skipping...
# Processing Record 23 of Set 7 | meadow lake
# Processing Record 24 of Set 7 | suozhen
# Processing Record 25 of Set 7 | mollendo
# Processing Record 26 of Set 7 | coleraine
# Processing Record 27 of Set 7 | russell
# Processing Record 28 of Set 7 | batyrevo
# Processing Record 29 of Set 7 | nicoya
# City not found. Skipping...
# Processing Record 30 of Set 7 | yashkino
# Processing Record 31 of Set 7 | kiama
# Processing Record 32 of Set 7 | miami
# City not found. Skipping...
# Processing Record 33 of Set 7 | garowe
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | emerald
# Processing Record 36 of Set 7 | cascais
# Processing Record 37 of Set 7 | port elizabeth
# Processing Record 38 of Set 7 | mandera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 7 | ulladulla
# Processing Record 40 of Set 7 | manggar
# Processing Record 41 of Set 7 | tevaitoa
# Processing Record 42 of Set 7 | goderich
# Processing Record 43 of Set 7 | san policarpo
# Processing Record 44 of Set 7 | scarborough
# Processing Record 45 of Set 7 | cifuentes
# Processing Record 46 of Set 7 | zhezkazgan
# Processing Record 47 of Set 7 | brae
# Processing Record 48 of Set 7 | carnarvon
# Processing Record 49 of Set 7 | landau
# Processing Record 50 of Set 7 | lompoc
# Processing Record 1 of Set 8 | chaiya
# City not found. Skipping...
# Processing Record 2 of Set 8 | aguimes
# Processing Record 3 of Set 8 | dunedin
# Processing Record 4 of Set 8 | sitka
# Processing Record 5 of Set 8 | shache
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | salisbury
# Processing Record 8 of Set 8 | nadym
# City not found. Skipping...
# Processing Record 9 of Set 8 | peace river
# Processing Record 10 of Set 8 | tilichiki
# Processing Record 11 of Set 8 | aykhal
# City not found. Skipping...
# Processing Record 12 of Set 8 | ozuluama
# Processing Record 13 of Set 8 | quelimane
# Processing Record 14 of Set 8 | kollo
# Processing Record 15 of Set 8 | abrau-dyurso
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | panzhihua
# Processing Record 18 of Set 8 | kaeo
# Processing Record 19 of Set 8 | saint stephen
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | marsa matruh
# Processing Record 22 of Set 8 | imbituba
# Processing Record 23 of Set 8 | matay
# Processing Record 24 of Set 8 | koslan
# Processing Record 25 of Set 8 | madang
# Processing Record 26 of Set 8 | caravelas
# Processing Record 27 of Set 8 | matara
# Processing Record 28 of Set 8 | chagoda
# Processing Record 29 of Set 8 | flin flon
# Processing Record 49 of Set 9 | tessalit
# Processing Record 50 of Set 9 | grudziadz
# Processing Record 1 of Set 10 | mezhdurechensk
# Processing Record 2 of Set 10 | pouembout
# City not found. Skipping...
# Processing Record 3 of Set 10 | fergus falls
# Processing Record 4 of Set 10 | bow island
# Processing Record 5 of Set 10 | puerto ayacucho
# Processing Record 6 of Set 10 | berekum
# Processing Record 7 of Set 10 | malaya serdoba
# Processing Record 8 of Set 10 | shenzhen
# Processing Record 9 of Set 10 | inuvik
# Processing Record 10 of Set 10 | itarema
# Processing Record 11 of Set 10 | zaykovo
# Processing Record 12 of Set 10 | qasigiannguit
# Processing Record 13 of Set 10 | bhola
# Processing Record 14 of Set 10 | salalah
# Processing Record 15 of Set 10 | golden
# Processing Record 16 of Set 10 | kimbe
# Processing Record 17 of Set 10 | malinovoye ozero
# Processing Record 18 of Set 10 | elektrenai
# Processing Record 19 of Set 10 | nizhniy odes
# Processing Record 20 of Set 10 | cabedelo
# Processing Record 21 of Set 10 | nivala
# Processing Record 22 of Set 10 | arraias
# Processing Record 23 of Set 10 | harindanga
# Processing Record 24 of Set 10 | ormara
# Processing Record 25 of Set 10 | dalvik
# Processing Record 26 of Set 10 | namibe
# Processing Record 27 of Set 10 | deer lake
# Processing Record 28 of Set 10 | anshun
# Processing Record 29 of Set 10 | swan river
# Processing Record 30 of Set 10 | marshall
# Processing Record 31 of Set 10 | wagar
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | mehran
# Processing Record 34 of Set 10 | onverwacht
# Processing Record 35 of Set 10 | hasaki
# Processing Record 36 of Set 10 | belaya gora
# Processing Record 37 of Set 10 | paradise
# Processing Record 38 of Set 10 | necochea
# Processing Record 39 of Set 10 | skreia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set 10 | padang
# Processing Record 41 of Set 10 | angoram
# Processing Record 42 of Set 10 | alexandria
# Processing Record 43 of Set 10 | olinda
# Processing Record 44 of Set 10 | ilhabela
# Processing Record 45 of Set 10 | kroya
# Processing Record 46 of Set 10 | buchanan
# Processing Record 47 of Set 10 | nago
# Processing Record 48 of Set 10 | barra dos coqueiros
# Processing Record 49 of Set 10 | dwarka
# Processing Record 50 of Set 10 | chadiza
# Processing Record 1 of Set 11 | pontianak
# City not found. Skipping...
# Processing Record 2 of Set 11 | nokaneng
# Processing Record 3 of Set 11 | abapo
# City not found. Skipping...
# Processing Record 4 of Set 11 | bozova
# City not found. Skipping...
# Processing Record 5 of Set 11 | jumla
# City not found. Skipping...
# Processing Record 6 of Set 11 | blagoyevo
# Processing Record 7 of Set 11 | mogadishu
# Processing Record 8 of Set 11 | byron bay
# Processing Record 9 of Set 11 | mnogovershinnyy
# Processing Record 10 of Set 11 | mabai
# Processing Record 11 of Set 11 | zhizdra
# Processing Record 12 of Set 11 | totma
# Processing Record 13 of Set 11 | bay city
# Processing Record 14 of Set 11 | uusikaupunki
# Processing Record 15 of Set 11 | camacari
# Processing Record 16 of Set 11 | makushino
# Processing Record 17 of Set 11 | lardos
# Processing Record 18 of Set 11 | havoysund
# Processing Record 19 of Set 11 | cristalina
# Processing Record 20 of Set 11 | iranshahr
# Processing Record 21 of Set 11 | el sauzal
# Processing Record 22 of Set 11 | newport
# Processing Record 23 of Set 11 | marawi
# Processing Record 24 of Set 11 | brigham city

# %%
# m = requests.get(query_url + "Paris").json()
# print(m)
# Out:
# {'coord': {'lon': 2.35, 'lat': 48.86}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 8.72, 'feels_like': 3.74, 'temp_min': 7.78, 'temp_max': 10, 'pressure': 1023, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 190}, 'clouds': {'all': 90}, 'dt': 1578010917, 'sys': {'type': 1, 'id': 6540, 'country': 'FR', 'sunrise': 1578037435, 'sunset': 1578067520}, 'timezone': 3600, 'id': 2988507, 'name': 'Paris', 'cod': 200}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame({
    'City':city_name,
    'Cloudiness':cloudiness,
    'Country':country_name,
    'Humidity':humidity,
    'Lat':lat,
    'Lng':lng,
    'Max Temp':max_temp,
    'Wind Speed':wind_speed
})
df.head(5)
# Out:
#              City  Cloudiness Country  Humidity    Lat     Lng  Max Temp  \
# 0    Punta Arenas          28      CL        41 -53.16  -70.91     13.94
# 1        Coihueco           0      CL        34 -36.63  -71.83     27.00
# 2         Rikitea          98      PF        72 -23.12 -134.97     26.51
# 3  Saint-Augustin          90      CA        74  45.63  -73.98      1.84
# 4         Mataura          67      NZ        73 -46.19  168.86     12.78
#
#    Wind Speed
# 0        4.60
# 1        4.60
# 2        2.47
# 3        6.20
# 4        6.71

# %%
df.to_csv("City_Data/City_Data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
s = df["Max Temp"].max()
s
# Out:
# 37.78

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df["Lat"], 
            df["Max Temp"],
            linewidths=1, marker="o", 
            alpha=0.8, cmap='plasma', edgecolors="black")

# set labels and sticks
plt.style.use('seaborn-bright')
plt.title(f"City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90, 90])
plt.ylim([df["Max Temp"].min() - 10, df["Max Temp"].max() + 10])

# Save the figure
plt.savefig("City_Data/Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df["Lat"], 
            df["Humidity"],
            linewidths=1, marker="o", 
            alpha=0.8, cmap='plasma', edgecolors="black")

# set labels and sticks
plt.style.use('seaborn-bright')
plt.title(f"City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90, 90])
plt.ylim([df["Humidity"].min() - 10, df["Humidity"].max() + 10])

# Save the figure
plt.savefig("City_Data/Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Lat"], 
            df["Cloudiness"],
            linewidths=1, marker="o", 
            alpha=0.8, cmap='plasma', edgecolors="black")

# set labels and sticks
plt.style.use('seaborn-bright')
plt.title(f"City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90, 90])
plt.ylim([df["Cloudiness"].min() - 10, df["Cloudiness"].max() + 10])

# Save the figure
plt.savefig("City_Data/Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Lat"], 
            df["Wind Speed"],
            linewidths=1, marker="o", 
            alpha=0.8, cmap='plasma', edgecolors="black")

# set labels and sticks
plt.style.use('seaborn-bright')
plt.title(f"City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-90, 90])
plt.ylim([df["Wind Speed"].min() - 10, df["Wind Speed"].max() + 10])

# Save the figure
plt.savefig("City_Data/Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
